# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
sample_list = [1.45965,1.46009,1.45871,1.46013,1.45871]
list2=[0.359949,0.357836, 0.359833, 0.362884, 0.361921]
list3=[0.59819,0.604543,0.6100662,0.592483]
list4=[0.378147,0.382494,0.385031,0.381494,0.377704]
list5=[0.705271,0.705973,0.704845,0.706591]
list6=[0.391139,0.392639,0.391946,0.395094,0.393625]
list7=[0.751343,0.752213,0.751478,0.751607,0.751471]
list8=[0.241827,0.245183,0.242526,0.244845,0.242645]
data = np.array(sample_list)
#plt.plot(sample_list)

plt.plot(list3)

plt.plot(list5)

plt.plot(list7)

plt.show()

# %%
plt.plot(list2)
plt.plot(list4)
plt.plot(list6)
plt.plot(list8)
plt.show()
